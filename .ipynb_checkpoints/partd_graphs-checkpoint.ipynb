# %%
import json
import sys
import os

import pprint as pp

sys.path.append('benchmarking/')
import util

import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# CREATE ALL OF THE PLOTS
filenames = ["listings_join_reviews.json"]
rename_data = ["q_listings_join_review"]


key_labels = [{
    "__": "no_index",
    "__datetime_in_reviews__": "datetime_index",
    "__id_in_listings__": "id_index",
    "__datetime_in_reviews__id_in_listings__": "datetime_and_id_index"
}]

for i, file in enumerate(filenames):
    key_label = key_labels[i]
    rename_string = rename_data[i]
    
    # Load JSON data from a file
    with open('perf_data/listings_join_reviews.json', 'r') as file:
        data = json.load(file)

    # Printing the loaded file
    #print(json.dumps(data, indent=4, sort_keys=True))
    
    data_renamed = util.rename_keys(data, rename_string)
    pp.pprint(data_renamed)
    
    
    avg_values = util.extract_values_with_metric(data_renamed, 'avg')
    pp.pprint(avg_values)
    std_values = util.extract_values_with_metric(data_renamed, 'std')
    
    # Prepare data for DataFrame
    data_for_df_avg = {label: [] for label in key_label.values()}
    data_for_df_avg['Year'] = sorted(avg_values.keys())
    
    data_for_df_std = {label: [] for label in key_label.values()}
    data_for_df_std['Year'] = sorted(std_values.keys())

    for year in data_for_df_avg['Year']:
        for key, label in key_label.items():
            data_for_df_avg[label].append(avg_values[year].get(key, None))
            data_for_df_std[label].append(std_values[year].get(key, None))

    # Create DataFrame
    df_avg = pd.DataFrame(data_for_df_avg)
    df_std = pd.DataFrame(data_for_df_std)

    # Set 'Year' as the index
    df_avg.set_index('Year', inplace=True)
    df_std.set_index('Year', inplace=True)

    # Display the DataFrame
    print(df_avg)
    
    for df, name in zip([df_avg, df_std],["Average","Standard Deviation"]):
    # Show the Plot for Average
        plt.figure(figsize=(12, 8))
        colors = ['red', 'green', 'blue', 'purple']
        # Calculate and plot average lines for each index across all years
        for idx, label in enumerate(key_label.values()):
            plt.plot(df.index, df[label], marker='o', label=label, color = colors[idx])
            avg_value = df[label].mean()
            plt.axhline(y=avg_value, linestyle='--', color=colors[idx], label=f'Average {label}')

        plt.title(f'{name} Query Time per Year')
        plt.xlabel('Year')
        plt.ylabel(f'{name} Query Time')
        plt.legend()
        plt.grid(True)
        plt.show()
# Out:
# {'2009': {'__': {'avg': 0.1404,
#                  'count': 50,
#                  'max': 0.1888,
#                  'min': 0.1332,
#                  'std': 0.0085,
#                  'timestamp': '2024-5-18-20:51:31'},
#           '__datetime_in_reviews__': {'avg': 0.0145,
#                                       'count': 50,
#                                       'max': 0.0178,
#                                       'min': 0.0135,
#                                       'std': 0.0007,
#                                       'timestamp': '2024-5-18-20:54:1'},
#           '__datetime_in_reviews__id_in_listings__': {'avg': 0.0229,
#                                                       'count': 50,
#                                                       'max': 0.0311,
#                                                       'min': 0.019,
#                                                       'std': 0.0016,
#                                                       'timestamp': '2024-5-18-20:58:11'},
#           '__id_in_listings__': {'avg': 0.1397,
#                                  'count': 50,
#                                  'max': 0.1465,
#                                  'min': 0.1374,
#                                  'std': 0.0017,
#                                  'timestamp': '2024-5-18-20:55:25'}},
#  '2010': {'__': {'avg': 0.1372,
#                  'count': 50,
#                  'max': 0.1447,
#                  'min': 0.1322,
#                  'std': 0.0032,
#                  'timestamp': '2024-5-18-20:51:38'},
#           '__datetime_in_reviews__': {'avg': 0.0147,
#                                       'count': 50,
#                                       'max': 0.0164,
#                                       'min': 0.0135,
#                                       'std': 0.0006,
#                                       'timestamp': '2024-5-18-20:54:2'},
#           '__datetime_in_reviews__id_in_listings__': {'avg': 0.0233,
#                                                       'count': 50,
#                                                       'max': 0.0259,
#                                                       'min': 0.0195,
#                                                       'std': 0.0013,
#                                                       'timestamp': '2024-5-18-20:58:13'},
#           '__id_in_listings__': {'avg': 0.1358,
#                                  'count': 50,
#                                  'max': 0.142,
#                                  'min': 0.1335,
#                                  'std': 0.0015,
#                                  'timestamp': '2024-5-18-20:55:32'}},
#  '2011': {'__': {'avg': 0.1367,
#                  'count': 50,
#                  'max': 0.1541,
#                  'min': 0.1291,
#                  'std': 0.0045,
#                  'timestamp': '2024-5-18-20:51:45'},
#           '__datetime_in_reviews__': {'avg': 0.0167,
#                                       'count': 50,
#                                       'max': 0.0192,
#                                       'min': 0.0158,
#                                       'std': 0.0009,
#                                       'timestamp': '2024-5-18-20:54:2'},
#           '__datetime_in_reviews__id_in_listings__': {'avg': 0.0261,
#                                                       'count': 50,
#                                                       'max': 0.0328,
#                                                       'min': 0.0208,
#                                                       'std': 0.0016,
#                                                       'timestamp': '2024-5-18-20:58:14'},
#           '__id_in_listings__': {'avg': 0.1577,
#                                  'count': 50,
#                                  'max': 0.221,
#                                  'min': 0.1315,
#                                  'std': 0.0378,
#                                  'timestamp': '2024-5-18-20:55:40'}},
#  '2012': {'__': {'avg': 0.1381,
#                  'count': 50,
#                  'max': 0.1584,
#                  'min': 0.1314,
#                  'std': 0.0045,
#                  'timestamp': '2024-5-18-20:51:51'},
#           '__datetime_in_reviews__': {'avg': 0.0196,
#                                       'count': 50,
#                                       'max': 0.0234,
#                                       'min': 0.0182,
#                                       'std': 0.001,
#                                       'timestamp': '2024-5-18-20:54:3'},
#           '__datetime_in_reviews__id_in_listings__': {'avg': 0.0302,
#                                                       'count': 50,
#                                                       'max': 0.0337,
#                                                       'min': 0.0262,
#                                                       'std': 0.0013,
#                                                       'timestamp': '2024-5-18-20:58:15'},
#           '__id_in_listings__': {'avg': 0.2116,
#                                  'count': 50,
#                                  'max': 0.2233,
#                                  'min': 0.1288,
#                                  'std': 0.0236,
#                                  'timestamp': '2024-5-18-20:55:50'}},
#  '2013': {'__': {'avg': 0.1403,
#                  'count': 50,
#                  'max': 0.1522,
#                  'min': 0.1333,
#                  'std': 0.0038,
#                  'timestamp': '2024-5-18-20:51:58'},
#           '__datetime_in_reviews__': {'avg': 0.0243,
#                                       'count': 50,
#                                       'max': 0.0332,
#                                       'min': 0.0228,
#                                       'std': 0.0017,
#                                       'timestamp': '2024-5-18-20:54:5'},
#           '__datetime_in_reviews__id_in_listings__': {'avg': 0.0365,
#                                                       'count': 50,
#                                                       'max': 0.0423,
#                                                       'min': 0.0226,
#                                                       'std': 0.0031,
#                                                       'timestamp': '2024-5-18-20:58:17'},
#           '__id_in_listings__': {'avg': 0.2185,
#                                  'count': 50,
#                                  'max': 0.2292,
#                                  'min': 0.136,
#                                  'std': 0.0149,
#                                  'timestamp': '2024-5-18-20:56:1'}},
#  '2014': {'__': {'avg': 0.1446,
#                  'count': 50,
#                  'max': 0.2729,
#                  'min': 0.136,
#                  'std': 0.0186,
#                  'timestamp': '2024-5-18-20:52:6'},
#           '__datetime_in_reviews__': {'avg': 0.0338,
#                                       'count': 50,
#                                       'max': 0.0773,
#                                       'min': 0.0312,
#                                       'std': 0.0064,
#                                       'timestamp': '2024-5-18-20:54:6'},
#           '__datetime_in_reviews__id_in_listings__': {'avg': 0.0464,
#                                                       'count': 50,
#                                                       'max': 0.091,
#                                                       'min': 0.0297,
#                                                       'std': 0.0104,
#                                                       'timestamp': '2024-5-18-20:58:20'},
#           '__id_in_listings__': {'avg': 0.216,
#                                  'count': 50,
#                                  'max': 0.268,
#                                  'min': 0.1332,
#                                  'std': 0.0268,
#                                  'timestamp': '2024-5-18-20:56:12'}},
#  '2015': {'__': {'avg': 0.1519,
#                  'count': 50,
#                  'max': 0.1952,
#                  'min': 0.1415,
#                  'std': 0.0091,
#                  'timestamp': '2024-5-18-20:52:13'},
#           '__datetime_in_reviews__': {'avg': 0.0536,
#                                       'count': 50,
#                                       'max': 0.0989,
#                                       'min': 0.0503,
#                                       'std': 0.0069,
#                                       'timestamp': '2024-5-18-20:54:9'},
#           '__datetime_in_reviews__id_in_listings__': {'avg': 0.0791,
#                                                       'count': 50,
#                                                       'max': 0.131,
#                                                       'min': 0.0625,
#                                                       'std': 0.0084,
#                                                       'timestamp': '2024-5-18-20:58:24'},
#           '__id_in_listings__': {'avg': 0.2296,
#                                  'count': 50,
#                                  'max': 0.2928,
#                                  'min': 0.1403,
#                                  'std': 0.0248,
#                                  'timestamp': '2024-5-18-20:56:24'}},
#  '2016': {'__': {'avg': 0.1903,
#                  'count': 50,
#                  'max': 0.2994,
#                  'min': 0.1492,
#                  'std': 0.0425,
#                  'timestamp': '2024-5-18-20:52:23'},
#           '__datetime_in_reviews__': {'avg': 0.0587,
#                                       'count': 50,
#                                       'max': 0.1044,
#                                       'min': 0.0546,
#                                       'std': 0.0091,
#                                       'timestamp': '2024-5-18-20:54:12'},
#           '__datetime_in_reviews__id_in_listings__': {'avg': 0.0606,
#                                                       'count': 50,
#                                                       'max': 0.1037,
#                                                       'min': 0.055,
#                                                       'std': 0.0099,
#                                                       'timestamp': '2024-5-18-20:58:27'},
#           '__id_in_listings__': {'avg': 0.2429,
#                                  'count': 50,
#                                  'max': 0.3023,
#                                  'min': 0.1519,
#                                  'std': 0.0246,
#                                  'timestamp': '2024-5-18-20:56:36'}},
#  '2017': {'__': {'avg': 0.2498,
#                  'count': 50,
#                  'max': 0.3068,
#                  'min': 0.1509,
#                  'std': 0.028,
#                  'timestamp': '2024-5-18-20:52:35'},
#           '__datetime_in_reviews__': {'avg': 0.0728,
#                                       'count': 50,
#                                       'max': 0.1198,
#                                       'min': 0.0661,
#                                       'std': 0.0129,
#                                       'timestamp': '2024-5-18-20:54:16'},
#           '__datetime_in_reviews__id_in_listings__': {'avg': 0.073,
#                                                       'count': 50,
#                                                       'max': 0.1194,
#                                                       'min': 0.0664,
#                                                       'std': 0.0136,
#                                                       'timestamp': '2024-5-18-20:58:30'},
#           '__id_in_listings__': {'avg': 0.1818,
#                                  'count': 50,
#                                  'max': 0.309,
#                                  'min': 0.1508,
#                                  'std': 0.0437,
#                                  'timestamp': '2024-5-18-20:56:45'}},
#  '2018': {'__': {'avg': 0.1679,
#                  'count': 50,
#                  'max': 0.21,
#                  'min': 0.1596,
#                  'std': 0.0135,
#                  'timestamp': '2024-5-18-20:52:44'},
#           '__datetime_in_reviews__': {'avg': 0.0935,
#                                       'count': 50,
#                                       'max': 0.139,
#                                       'min': 0.0864,
#                                       'std': 0.0125,
#                                       'timestamp': '2024-5-18-20:54:20'},
#           '__datetime_in_reviews__id_in_listings__': {'avg': 0.0935,
#                                                       'count': 50,
#                                                       'max': 0.1376,
#                                                       'min': 0.0868,
#                                                       'std': 0.0124,
#                                                       'timestamp': '2024-5-18-20:58:35'},
#           '__id_in_listings__': {'avg': 0.1665,
#                                  'count': 50,
#                                  'max': 0.2102,
#                                  'min': 0.1618,
#                                  'std': 0.0112,
#                                  'timestamp': '2024-5-18-20:56:53'}},
#  '2019': {'__': {'avg': 0.382,
#                  'count': 50,
#                  'max': 0.4311,
#                  'min': 0.3611,
#                  'std': 0.018,
#                  'timestamp': '2024-5-18-20:53:3'},
#           '__datetime_in_reviews__': {'avg': 0.3903,
#                                       'count': 50,
#                                       'max': 0.4412,
#                                       'min': 0.3676,
#                                       'std': 0.0185,
#                                       'timestamp': '2024-5-18-20:54:40'},
#           '__datetime_in_reviews__id_in_listings__': {'avg': 0.3937,
#                                                       'count': 50,
#                                                       'max': 0.4478,
#                                                       'min': 0.3773,
#                                                       'std': 0.0189,
#                                                       'timestamp': '2024-5-18-20:58:55'},
#           '__id_in_listings__': {'avg': 0.3842,
#                                  'count': 50,
#                                  'max': 0.4392,
#                                  'min': 0.3626,
#                                  'std': 0.0184,
#                                  'timestamp': '2024-5-18-20:57:12'}},
#  '2020': {'__': {'avg': 0.1604,
#                  'count': 50,
#                  'max': 0.2033,
#                  'min': 0.1531,
#                  'std': 0.0139,
#                  'timestamp': '2024-5-18-20:53:11'},
#           '__datetime_in_reviews__': {'avg': 0.0698,
#                                       'count': 50,
#                                       'max': 0.1141,
#                                       'min': 0.0622,
#                                       'std': 0.014,
#                                       'timestamp': '2024-5-18-20:54:43'},
#           '__datetime_in_reviews__id_in_listings__': {'avg': 0.0713,
#                                                       'count': 50,
#                                                       'max': 0.1263,
#                                                       'min': 0.0625,
#                                                       'std': 0.0177,
#                                                       'timestamp': '2024-5-18-20:58:58'},
#           '__id_in_listings__': {'avg': 0.1688,
#                                  'count': 50,
#                                  'max': 0.2393,
#                                  'min': 0.1508,
#                                  'std': 0.0194,
#                                  'timestamp': '2024-5-18-20:57:21'}},
#  '2021': {'__': {'avg': 0.3873,
#                  'count': 50,
#                  'max': 0.7936,
#                  'min': 0.3651,
#                  'std': 0.0617,
#                  'timestamp': '2024-5-18-20:53:30'},
#           '__datetime_in_reviews__': {'avg': 0.1271,
#                                       'count': 50,
#                                       'max': 0.1785,
#                                       'min': 0.1062,
#                                       'std': 0.0193,
#                                       'timestamp': '2024-5-18-20:54:50'},
#           '__datetime_in_reviews__id_in_listings__': {'avg': 0.1296,
#                                                       'count': 50,
#                                                       'max': 0.1892,
#                                                       'min': 0.1116,
#                                                       'std': 0.0202,
#                                                       'timestamp': '2024-5-18-20:59:5'},
#           '__id_in_listings__': {'avg': 0.3796,
#                                  'count': 50,
#                                  'max': 0.4279,
#                                  'min': 0.3657,
#                                  'std': 0.0195,
#                                  'timestamp': '2024-5-18-20:57:40'}},
#  '2022': {'__': {'avg': 0.1974,
#                  'count': 50,
#                  'max': 0.2587,
#                  'min': 0.1817,
#                  'std': 0.0215,
#                  'timestamp': '2024-5-18-20:53:40'},
#           '__datetime_in_reviews__': {'avg': 0.2405,
#                                       'count': 50,
#                                       'max': 0.2809,
#                                       'min': 0.224,
#                                       'std': 0.0199,
#                                       'timestamp': '2024-5-18-20:55:2'},
#           '__datetime_in_reviews__id_in_listings__': {'avg': 0.2411,
#                                                       'count': 50,
#                                                       'max': 0.2828,
#                                                       'min': 0.227,
#                                                       'std': 0.0202,
#                                                       'timestamp': '2024-5-18-20:59:17'},
#           '__id_in_listings__': {'avg': 0.196,
#                                  'count': 50,
#                                  'max': 0.2374,
#                                  'min': 0.1827,
#                                  'std': 0.0196,
#                                  'timestamp': '2024-5-18-20:57:50'}},
#  '2023': {'__': {'avg': 0.2141,
#                  'count': 50,
#                  'max': 0.2521,
#                  'min': 0.1977,
#                  'std': 0.0218,
#                  'timestamp': '2024-5-18-20:53:51'},
#           '__datetime_in_reviews__': {'avg': 0.2965,
#                                       'count': 50,
#                                       'max': 0.3398,
#                                       'min': 0.2658,
#                                       'std': 0.0222,
#                                       'timestamp': '2024-5-18-20:55:17'},
#           '__datetime_in_reviews__id_in_listings__': {'avg': 0.297,
#                                                       'count': 50,
#                                                       'max': 0.3402,
#                                                       'min': 0.2671,
#                                                       'std': 0.0227,
#                                                       'timestamp': '2024-5-18-20:59:32'},
#           '__id_in_listings__': {'avg': 0.2151,
#                                  'count': 50,
#                                  'max': 0.2522,
#                                  'min': 0.1979,
#                                  'std': 0.0225,
#                                  'timestamp': '2024-5-18-20:58:0'}},
#  '2024': {'__': {'avg': 0.1776,
#                  'count': 50,
#                  'max': 0.2304,
#                  'min': 0.1336,
#                  'std': 0.0429,
#                  'timestamp': '2024-5-18-20:54:0'},
#           '__datetime_in_reviews__': {'avg': 0.0308,
#                                       'count': 50,
#                                       'max': 0.0739,
#                                       'min': 0.0277,
#                                       'std': 0.0064,
#                                       'timestamp': '2024-5-18-20:55:18'},
#           '__datetime_in_reviews__id_in_listings__': {'avg': 0.0311,
#                                                       'count': 50,
#                                                       'max': 0.0746,
#                                                       'min': 0.0283,
#                                                       'std': 0.0065,
#                                                       'timestamp': '2024-5-18-20:59:33'},
#           '__id_in_listings__': {'avg': 0.1795,
#                                  'count': 50,
#                                  'max': 0.2292,
#                                  'min': 0.137,
#                                  'std': 0.0417,
#                                  'timestamp': '2024-5-18-20:58:9'}}}
# {'2009': {'__': 0.1404,
#           '__datetime_in_reviews__': 0.0145,
#           '__datetime_in_reviews__id_in_listings__': 0.0229,
#           '__id_in_listings__': 0.1397},
#  '2010': {'__': 0.1372,
#           '__datetime_in_reviews__': 0.0147,
#           '__datetime_in_reviews__id_in_listings__': 0.0233,
#           '__id_in_listings__': 0.1358},
#  '2011': {'__': 0.1367,
#           '__datetime_in_reviews__': 0.0167,
#           '__datetime_in_reviews__id_in_listings__': 0.0261,
#           '__id_in_listings__': 0.1577},
#  '2012': {'__': 0.1381,
#           '__datetime_in_reviews__': 0.0196,
#           '__datetime_in_reviews__id_in_listings__': 0.0302,
#           '__id_in_listings__': 0.2116},
#  '2013': {'__': 0.1403,
#           '__datetime_in_reviews__': 0.0243,
#           '__datetime_in_reviews__id_in_listings__': 0.0365,
#           '__id_in_listings__': 0.2185},
#  '2014': {'__': 0.1446,
#           '__datetime_in_reviews__': 0.0338,
#           '__datetime_in_reviews__id_in_listings__': 0.0464,
#           '__id_in_listings__': 0.216},
#  '2015': {'__': 0.1519,
#           '__datetime_in_reviews__': 0.0536,
#           '__datetime_in_reviews__id_in_listings__': 0.0791,
#           '__id_in_listings__': 0.2296},
#  '2016': {'__': 0.1903,
#           '__datetime_in_reviews__': 0.0587,
#           '__datetime_in_reviews__id_in_listings__': 0.0606,
#           '__id_in_listings__': 0.2429},
#  '2017': {'__': 0.2498,
#           '__datetime_in_reviews__': 0.0728,
#           '__datetime_in_reviews__id_in_listings__': 0.073,
#           '__id_in_listings__': 0.1818},
#  '2018': {'__': 0.1679,
#           '__datetime_in_reviews__': 0.0935,
#           '__datetime_in_reviews__id_in_listings__': 0.0935,
#           '__id_in_listings__': 0.1665},
#  '2019': {'__': 0.382,
#           '__datetime_in_reviews__': 0.3903,
#           '__datetime_in_reviews__id_in_listings__': 0.3937,
#           '__id_in_listings__': 0.3842},
#  '2020': {'__': 0.1604,
#           '__datetime_in_reviews__': 0.0698,
#           '__datetime_in_reviews__id_in_listings__': 0.0713,
#           '__id_in_listings__': 0.1688},
#  '2021': {'__': 0.3873,
#           '__datetime_in_reviews__': 0.1271,
#           '__datetime_in_reviews__id_in_listings__': 0.1296,
#           '__id_in_listings__': 0.3796},
#  '2022': {'__': 0.1974,
#           '__datetime_in_reviews__': 0.2405,
#           '__datetime_in_reviews__id_in_listings__': 0.2411,
#           '__id_in_listings__': 0.196},
#  '2023': {'__': 0.2141,
#           '__datetime_in_reviews__': 0.2965,
#           '__datetime_in_reviews__id_in_listings__': 0.297,
#           '__id_in_listings__': 0.2151},
#  '2024': {'__': 0.1776,
#           '__datetime_in_reviews__': 0.0308,
#           '__datetime_in_reviews__id_in_listings__': 0.0311,
#           '__id_in_listings__': 0.1795}}
#       no_index  datetime_index  id_index  datetime_and_id_index
# Year
# 2009    0.1404          0.0145    0.1397                 0.0229
# 2010    0.1372          0.0147    0.1358                 0.0233
# 2011    0.1367          0.0167    0.1577                 0.0261
# 2012    0.1381          0.0196    0.2116                 0.0302
# 2013    0.1403          0.0243    0.2185                 0.0365
# 2014    0.1446          0.0338    0.2160                 0.0464
# 2015    0.1519          0.0536    0.2296                 0.0791
# 2016    0.1903          0.0587    0.2429                 0.0606
# 2017    0.2498          0.0728    0.1818                 0.0730
# 2018    0.1679          0.0935    0.1665                 0.0935
# 2019    0.3820          0.3903    0.3842                 0.3937
# 2020    0.1604          0.0698    0.1688                 0.0713
# 2021    0.3873          0.1271    0.3796                 0.1296
# 2022    0.1974          0.2405    0.1960                 0.2411
# 2023    0.2141          0.2965    0.2151                 0.2970
# 2024    0.1776          0.0308    0.1795                 0.0311
# 1
# 2
